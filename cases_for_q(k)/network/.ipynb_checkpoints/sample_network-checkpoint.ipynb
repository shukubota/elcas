# %%
from networkx_func import *

# %%
def mul_700(x):
    return x*700

# %%
# q(k) ~ k
nwdata1 = np.load('./ad_list/alpha1_nwdata.npy')

def func1(x):
    return (x**1.5)*5.0

OutputNGraph(nwdata1, 100, func1, 0.15, 'alpha1.png')

# %%
# q(k) ~ k+3
nwdata1 = np.load('./ad_list/k+3_nwdata.npy')

def func1(x):
    return (x**1.5)*5.0

OutputNGraph(nwdata1, 100, func1, 0.15, 'k+3.png')

# %%
# q(k) ~ k**2
nwdata1 = np.load('./ad_list/alpha2_nwdata.npy')

def func1(x):
    return (x**1.5)*5.0

OutputNGraph(nwdata1, 100, func1, 0.15, 'alpha2.png')

# %%
# q(k) ~ k**0.5
nwdata1 = np.load('./ad_list/alpha05_nwdata.npy')

def func1(x):
    return (x**1.5)*5.0

OutputNGraph(nwdata1, 100, func1, 0.15, 'alpha05.png')

# %%
# q(k) ~ 1
nwdata1 = np.load('./ad_list/alpha0_nwdata.npy')

def func1(x):
    return (x**1.5)*5.0

OutputNGraph(nwdata1, 100, func1, 0.15, 'alpha0.png')

# %%
# q(k) ~ 1/k
nwdata1 = np.load('./ad_list/alpha-1_nwdata.npy')

def func1(x):
    return (x**1.5)*5.0

OutputNGraph(nwdata1, 100, func1, 0.15, 'alpha-1.png')

# %%
# q(k) ~ log10(k)
nwdata1 = np.load('./ad_list/log10_nwdata.npy')

def func1(x):
    return (x**1.5)*5.0

OutputNGraph(nwdata1, 100, func1, 0.15, 'log10.png')

# %%
# q(k) ~ 1.5**k
nwdata1 = np.load('./ad_list/1p5power_nwdata.npy')

def func1(x):
    return (x**1.5)*5.0

OutputNGraph(nwdata1, 100, func1, 0.15, '1p5power.png')
